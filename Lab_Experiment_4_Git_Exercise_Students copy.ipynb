# %% [markdown]
# # 💻 Lab Experiment 4: How to Use Git Effectively
#
# ### **Objectives**
# 1. Understand the purpose of version control systems.
# 2. Learn how to set up and configure Git.
# 3. Practice essential Git commands for managing code effectively.
# 4. Explore collaboration workflows with branching and merging.
#
# ---

# %% [markdown]
# # Step 1: Install and Configure Git

# %%
# !git --version

# Configure Git user details (replace with your name & email)
# !git config --global user.name "Your Name"
# !git config --global user.email "your.email@example.com"

# Verify configuration
# !git config --list
# Out:
# git version 2.50.1 (Apple Git-155)
# credential.helper=osxkeychain
# init.defaultbranch=main
# user.name=Your Name
# user.email=your.email@example.com
# core.repositoryformatversion=0
# core.filemode=true
# core.bare=false
# core.logallrefupdates=true
# core.ignorecase=true
# core.precomposeunicode=true
# remote.origin.url=https://github.com/Prashant-singh-007/Python-Assignment.git
# remote.origin.fetch=+refs/heads/*:refs/remotes/origin/*
# branch.main.vscode-merge-base=origin/main
# branch.new_feature.vscode-merge-base=origin/main

# %% [markdown]
# # Step 2: Create a New Repository

# %%
# !git init
# !ls
# Out:
# Reinitialized existing Git repository in /Users/prashantsinghnegi/Downloads/my_project/my_project/.git/
# Assignment 6.ipynb
# Assignment1.ipynb
# Assignment2.ipynb
# LAB5_(1).ipynb
# Lab_Experiment_4_Git_Exercise_Students.ipynb
# assignent3 (1).ipynb
# feature.txt
# file.txt

# %% [markdown]
# # Step 3: Add and Commit Files

# %%
# !echo "Hello Git" > file.txt
# !git status
# Out:
# On branch main
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	Assignment 6.ipynb
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !git add .
# !git status
# !git commit -m "Initial commit with file.txt"
# Out:
# On branch main
# Changes to be committed:
#   (use "git restore --staged <file>..." to unstage)
# 	new file:   Assignment 6.ipynb
#
# [main 891a0c2] Initial commit with file.txt
#  1 file changed, 1655 insertions(+)
#  create mode 100644 Assignment 6.ipynb

# %%
# !git log --oneline
# Out:
# 891a0c2 (HEAD -> main) Initial commit with file.txt
# 071d7b2 (origin/main, origin/HEAD) Initial commit with file.txt
# af51810 (new_feature) Initial commit with file.txt
# 60d764a Added new feature file
# 9094061 Initial commit with file.txt

# %% [markdown]
# # Step 4: Create and Switch Branches

# %%
# !git branch
# Out:
# * main
#   new_feature

# %%
# !git branch new_feature
# Out:
# fatal: a branch named 'new_feature' already exists

# %%
# !git branch
# Out:
# * main
#   new_feature

# %%
# !git checkout new_feature
# Out:
# Switched to branch 'new_feature'

# %%
# !git branch
# Out:
#   main
# * new_feature

# %%
# !echo "This is a new feature!" > feature.txt

# %%
# !git status
# Out:
# On branch new_feature
# nothing to commit, working tree clean

# %%
# !git add feature.txt

# %%
# !git status
# Out:
# On branch new_feature
# nothing to commit, working tree clean

# %%
# !git commit -m "Added new feature file"
# Out:
# On branch new_feature
# nothing to commit, working tree clean

# %%
# !git branch
# Out:
#   main
# * new_feature

# %%
# !git status
# Out:
# On branch new_feature
# nothing to commit, working tree clean

# %% [markdown]
# # Step 5: Merge Branches

# %%
# !git checkout main
# !git merge new_feature
# !ls
# Out:
# Switched to branch 'main'
# Already up to date.
# Assignment 6.ipynb
# Assignment1.ipynb
# Assignment2.ipynb
# LAB5_(1).ipynb
# Lab_Experiment_4_Git_Exercise_Students.ipynb
# assignent3 (1).ipynb
# feature.txt
# file.txt

# %% [markdown]
# # Step 6: Connect to Remote Repository

# %%
# !git remote add origin https://github.com/Prashant-singh-007/Python-Assignment.git
# Out:
# error: remote origin already exists.

# %%
# !git remote -v
# Out:
# origin	https://github.com/Prashant-singh-007/Python-Assignment.git (fetch)
# origin	https://github.com/Prashant-singh-007/Python-Assignment.git (push)

# %%
# Uncomment below line to push (if authenticated)
# !git push -f origin main
# Out:
# Enumerating objects: 4, done.
# Counting objects: 100% (4/4), done.
# Delta compression using up to 10 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 273.97 KiB | 18.26 MiB/s, done.
# Total 3 (delta 1), reused 0 (delta 0), pack-reused 0 (from 0)
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/Prashant-singh-007/Python-Assignment.git
#    071d7b2..891a0c2  main -> main

# %% [markdown]
# ### 🧭 Common Git Commands Reference
#
# | Command | Description |
# |----------|-------------|
# | `git init` | Initialize a repository |
# | `git status` | Show file status |
# | `git add <file>` | Stage file changes |
# | `git commit -m "msg"` | Save staged changes with a message |
# | `git branch` | List branches |
# | `git checkout <branch>` | Switch branches |
# | `git merge <branch>` | Merge a branch into the current branch |
# | `git push` | Upload local changes to remote |
#
# ---
